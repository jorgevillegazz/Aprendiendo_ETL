# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgevillegazz/Aprendiendo_ETL/blob/main/Pandas_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01 - Leyendo archivos .csv

# %% [markdown]
# La abreviatura "CSV" significa "valores separados por comas" (del inglés 'comma separated value')

# %% [markdown]
# Imaginemos que trabajamos para una gran cadena de supermercados, Estrella de Belén, esta cadena de supermercados quiere ofrecer un buen descuento, digamos del 20%, a sus mejores clientes, un descuento de promoción, van a hacer una liquidación de fin de año.
#
# Pero no saben a quién dar este descuento, no saben quiénes son sus mejores clientes, saben que tiene que ver, que está relacionado con el poder de compra del cliente, cuánto gastó en el año, cuántas veces viene al mercado, etc. Pero no tienen ni idea de por dónde empezar.
#
# Lo que sí saben es que tienen que trabajar con la base de clientes de este supermercado. Entonces llaman al científico de datos, en este caso, nosotros, y nos indican que hagamos un levantamiento, una extracción de las informaciones más relevantes para poder identificar quiénes son sus mejores clientes para poder ofrecerles esta información.
#
# Así que nos llaman y nos dicen necesitamos identificar a los mejores clientes,  Entonces te voy a pasar aquí mi base de clientes y tú me vas a extraer, vas a importar, vas a extraer esta información, vas a levantar estos datos y nos vas a traer las informaciones o los campos, los atributos más relevantes para poder identificar quiénes son nuestros mejores clientes, Así es como nos piden a nosotros el trabajo.

# %% [markdown]
# ##Importando Archivos .CSV

# %% [markdown]
# Entonces vamos a importar la biblioteca Pandas y le vamos a llamar pd, Para que sea más fácil de invocar a la biblioteca Pandas durante el código

# %%
import pandas as pd

# %% [markdown]
# Ahora vamos a utilizar el método de Pandas que se utiliza para leer archivos CSV. Ya no  escribo pandas, ahora  Escribo pd, porque esa es la forma en que le estoy llamando ahora, es su nuevo nombre, más cortito, pero es igual, es Pandas. Y el método para leer archivos CSV es read_csv

# %%
pd.read_csv('superstore_data.csv')
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ¿dónde lo voy a guardar? Voy a crear una nueva variable que le voy a llamar datos y voy a asignarle el resultado de la lectura del archivo CSV. Es decir, que una vez que lo lea, este archivo se va a guardar en datos, pero ¿se va a guardar cómo? ¿De la misma forma que lo vimos aquí? ¿En esta forma bruta, por decirlo así? No, ¿verdad? Cuando se lee con Pandas, automáticamente este archivo se transforma en un ***dataframe***

# %%
datos = pd.read_csv('superstore_data.csv')

# %%
datos
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# para visualizar las primeras 5 lineas  de nuestro df(dataframe) usaremoe el comando .head

# %%
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# Pero, ¿qué sucedería si el archivo no estuviera separado por comas? Recuerden que el CSV estaba separado por comas, Yo tengo otro archivo que es el superstardata.coma Lo voy a abrir con el mismo editor. Y miren Este archivo es el mismo archivo, solo que, si ustedes ven, la separación ya no es por coma, sino es por punto y coma,  Es diferente. ¿Será que se va a subir de la misma forma en el Google Colab con Python? ¿Será que lo va a leer aunque esté separado por puntos y comas? Veamos. Vamos a descubrirlo ya

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
datos_punto_y_coma= pd.read_csv('superstore_data_punto_coma.csv')# se cambio el nombre de la variable df para no confundirnos

# %%
datos_punto_y_coma.head()
# Out:
#   Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0  1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1  1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2  10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3  1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4  5371;1989;Graduation;Single;21474;1;0;8/4/2014...

# %% [markdown]
# Oh, y ustedes pueden ver... ¿Qué? Que no pueden ver nada, ¿verdad? ¿Por qué? Porque no ha aparecido en formato tabla. ¿Qué es lo que ha sucedido aquí? Como ustedes pueden ver aquí, los datos no están similares a como si estuvieran con la coma. Cuando el archivo tiene punto y coma, el comando read_csv intentó buscar la coma, que es el separador de las columnas. Como no la encontró, asumió que toda esa línea era un único atributo y la subió de esa manera. Que no es la correcta

# %% [markdown]
# ###Para saber más: error de codificación - ¿cómo solucionarlo?
#
# Giovanna es una científica de datos que trabaja en una empresa de comercio electrónico. Ella es responsable de analizar datos de ventas para identificar patrones y tendencias que puedan ayudar a la empresa a tomar decisiones informadas.
#
# Recientemente, le asignaron una nueva tarea: analizar un archivo CSV que contiene información sobre las ventas de la empresa durante un período determinado. Para ello, Giovanna intentó leer un archivo CSV en Google Colab, usando la biblioteca Pandas con el siguiente comando:
#
# import pandas as pd
#
# df = pd.read_csv('datos.csv')
#
# Sin embargo, apareció el siguiente error:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En español, el mensaje significa UnicodeDecodeError: el códec 'utf-8' no puede decodificar el byte 0xff en la posición 0: byte de inicio inválido
#
# Pero ¿qué significa eso? ¿Qué es esto de UTF-8?
#
# El error de encoding ocurre cuando la biblioteca Pandas no puede interpretar correctamente los caracteres en un archivo CSV. Esto puede suceder cuando contiene caracteres especiales que la biblioteca Pandas no reconoce o cuando se guardó en un formato de codificación diferente al esperado.
#
# Para resolver este error, es necesario identificar la codificación correcta del archivo CSV y especificarla al cargar el archivo con la biblioteca Pandas. Esta codificación predeterminada es UTF-8, pero en algunos casos, es posible que el archivo se haya guardado con una codificación diferente, como ISO-8859-1.
#
# UTF-8 es una codificación de caracteres universal que se utiliza para representar caracteres de diferentes idiomas de una manera compatible con Internet y los sistemas de computadora en general. Las siglas UTF significan Unicode Transformation Format (Formato de Transformación Unicode) y el número 8 indica que esta codificación asocia una secuencia de 1 a 4 bytes (8 a 32 bits) a cada carácter.
#
# La codificación UTF-8 se usa ampliamente en Internet y en sistemas informáticos de todo el mundo, ya que permite representar caracteres de diferentes idiomas en un solo conjunto de caracteres. Además, esta codificación puede preservar la compatibilidad con codificaciones más antiguas como ASCII, lo que la convierte en una opción popular para crear y compartir archivos de texto.
#
# Quizás estés pensando ahora mismo: ¿cómo podría Giovanna descubrir cuál es la codificación del archivo que está intentando leer?
#
# Hay algunas formas de resolver esto, sin embargo, tendremos la oportunidad de experimentar una forma práctica de hacerlo en el propio Google Colab. ¿Vamos allá?
#
# Podemos usar una biblioteca llamada [chardet](https://pypi.org/project/chardet/) para detectar el encoding de un archivo CSV. Para usar esta biblioteca en Google Colab, simplemente importela:

# %% [markdown]
# import chardet
#
# Luego escribimos el siguiente bloque de código:
#
#    with open('datos.csv', 'rb') as file:
#
#       print(chardet.detect(file.read()))
#
#
# Observe que la primera línea de este código abre el archivo CSV en modo de lectura binaria rb y asigna el objeto del archivo devuelto a una variable llamada file.
#
# En la segunda línea de código, el contenido del archivo CSV se lee usando el método read() y el resultado se pasa a la función chardet.detect(), que devuelve un diccionario que contiene información sobre la codificación más probable del archivo. El resultado se imprime con la función print() que muestra la codificación y la confianza asociada con esa codificación.
#
# Al ejecutar el código Giovanna obtuvo el siguiente resultado:

# %% [markdown]
# {'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}
#
# Ahora ella sabe que es probable que el archivo CSV esté codificado con UTF-16 con una confianza de 1.0. Para especificar la codificación correcta al cargar el archivo CSV con la biblioteca Pandas, puede utilizar un parámetro llamado encoding:
#
# df = pd.read_csv('datos.csv', encoding='UTF-16')
#
# De esta manera, la biblioteca Pandas cargará el archivo CSV usando la codificación UTF-16, lo que resolverá el error de codificación. Entonces, si alguna vez intentas leer un archivo y obtienes el mismo error, ¡recuerda este consejo!
#
# Si deseas profundizar más en el tema, aquí te dejamos algunos enlaces a materiales que fueron utilizados como referencia:

# %% [markdown]
# * [Instituto de Matemáticas y Estadística - IME/USP: Unicode y UTF-8](https://www.ime.usp.br/~pf/algoritmos/apend/unicode.html#detection)
#
# * [IBM: ¿Qué es Unicode?](https://www.ibm.com/docs/pt-br/workload-automation/9.3.0)
#
# * [Kaggle: codificaciones de caracteres](https://www.kaggle.com/code/alexisbcook/character-encodings/tutorial)

# %% [markdown]
# ##**Parámetros de la función read_csv**
#
# *   Elemento de lista
# *   Elemento de lista
#
#
# Documentación: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %% [markdown]
# Volviendo al tema  del problema del punto y coma ";", par asolucionarlo  tendremos que agregar el parametro (,sep =";")

# %%
datos_punto_y_coma= pd.read_csv('superstore_data_punto_coma.csv',sep = ";")# se le agrego el separador ;

# %%
datos_punto_y_coma
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# Ahora si problema resuelto

# %% [markdown]
# Vamos a practicar con otros parametros de la documentacion de pandas.read por ejemplo usaremos el ***nrow***

# %%
datos_primeras_lineas = pd.read_csv('superstore_data.csv',nrows=5)
datos_primeras_lineas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %% [markdown]
# ***nrow*** nos ayuda a visualizar  las  filas que deseamos de nustro  df,  en esre caso  pusismos las primeras  5

# %%
datos_seleccion = pd.read_csv('superstore_data.csv', usecols=['Id', 'Year_Birth', 'Income'])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ***usecols*** nos permite visualizar  solo las  columnas  que deseamos
#
# usecols=['Id', 'Year_Birth', 'Income']
#
# en este caso  deseamo especificar  solo estas  tres columnas

# %%
datos_seleccion = pd.read_csv('superstore_data.csv', usecols=[0,1,4])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# tambien se podra  usar de esta manera  especificando el indice del arreglo de la columna
#
#  usecols=[0,1,4]

# %% [markdown]
# ##Escribiendo archivos csv

# %% [markdown]
# Documentación: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

# %% [markdown]
# teniendo la variable "datos_seleccion" le agregamos ".to_csv('nombre_del_archivo.csv')"
# Así podemos guardar  los archviso  con los datos  necesarios para  poder trabajar

# %%
datos_seleccion.to_csv('clientes_mercado.csv')

# %% [markdown]
# Ahora podremos visualizar el archivo que se creo para  comprobar  que todo este  bien

# %%
clientes_mercado =pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %% [markdown]
# Aqui podemos observar  que al momento de guardar  se genero una columna de más, la cual se llama " Unnamed: 0	" que basicamente es un índice

# %% [markdown]
# PAra solucionar este problema  existe  otro parámetro en ".to_csv " llamdo "index"
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Este parámetro index va a escribir el nombre de los índices como columna en nuestro resultado y el valor es, por defecto, true. Es decir, que si nosotros no quiero el índice, le ponemos false

# %%
datos_seleccion.to_csv('datos_mercado.csv',index=False)# Cambiamos el nombre del archivo para no confundirnos a datos_mercado

# %%
datos_mercado = pd.read_csv('datos_mercado.csv' )
datos_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# Ahora sí problema corregido!!!

# %% [markdown]
# ************************************************************************************

# %% [markdown]
# ###**Desafío: leyendo datos con múltiples parámetros**
#
# Es hora de que pongas a prueba los conocimientos desarrollados durante la clase. Disponemos de un archivo en formato CSV, el cual se obtuvo de la página Información de Salud (TABNET) - DATASUS. Este archivo contiene los gastos hospitalarios públicos de cada una de las Unidades de la Federación Brasileña desde enero de 2008 hasta marzo de 2021.
#
# Su desafío aquí será leer este archivo usando la función read_csv de la biblioteca Pandas. Se deben agregar algunos parámetros para que la lectura se realice correctamente. Entonces, aquí hay algunos consejos:
#
# 1. Asegúrese de que el archivo CSV esté separado por una coma o punto y coma.
# 2. La codificación del archivo es ISO-8859-1.
# 3. Las primeras tres líneas del archivo se pueden ignorar, ya que el encabezado sólo comienza en la cuarta línea.
# 4. Las últimas 9 líneas también se pueden ignorar, ya que son sólo información sobre dónde se tomaron los datos.
# 5. Para eliminar las últimas líneas es necesario agregar el parámetro engine='python'.

# %% [markdown]
# Para leer el archivo podemos comenzar almacenando la dirección en una variable llamada url:

# %%
url='https://raw.githubusercontent.com/alura-es-cursos/1980-Pandas_IO/datos_sus/datos_sus.csv'

# %% [markdown]
# Luego podemos leer la url con la función read_csv y agregar los parámetros:
#
# 1. encoding='ISO-8859-1': tipo de codificación de caracteres del archivo. En este caso, es la codificación ISO-8859-1 la que es común en los archivos en idioma portugués.
# 2. sep=';': separador de los valores del archivo. En este caso, es el punto y coma (;).
# 3. skiprows=3: indica que las primeras tres líneas del archivo deben ignorarse ya que no contienen datos relevantes.
# 4. skipfooter=9: Indica que las últimas nueve líneas del archivo deben ignorarse ya que no contienen datos relevantes.
# 5. engine='python': el motor utilizado para leer el archivo es Python. Esto es necesario cuando se utiliza el parámetro skipfooter, ya que el motor predeterminado no admite esta opción.

# %%
datos_hospital = pd.read_csv(url, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')

# %% [markdown]
# ¡De esta manera los datos se cargarán exitosamente!

# %%
datos_hospital
# Out:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# ##Lo que aprendimos
#
# En esta aula, aprendimos:
#
# 1. Entender qué es un archivo CSV;
# 2. Leer un archivo en formato CSV separado por comas y punto y coma;
# 3. Leer sólo unas pocas líneas y también columnas específicas de un archivo en formato CSV;
# 4. Escribir un archivo en formato CSV.

# %% [markdown]
# #**Aula 2 - Leyendo archivos Excel**

# %% [markdown]
# ##**Importando archivos Excel**

# %%
import pandas as pd

# %% [markdown]
# Antes de importar el archivo, voy a guardar el nombre del archivo para no estar escribiendo y copiando y pegando todo el tiempo. En esta variable, voy a crear una variable archivo y voy a colocar entre las comillas simples el nombre del archivo. De esta manera, no tengo que estar escribiendo a toda hora emisiones CO2, emisiones CO2, emisiones CO2, sino que ya referencio a la variable archivo. Esto es para optimizar el código.

# %%
archivo = 'emisiones_CO2.xlsx'

# %% [markdown]
# Antes para leer  los archivos era con .read_csv,  ahora será .read_excel()

# %%
datos_co2 = pd.read_excel(archivo)

# %% [markdown]
# Aquí ya estoy importando el archivo Excel, todo su contenido dentro de una variable datos_co2;  datos_co2 automáticamente se convierte en un dataframe porque este método devuelve un dataframe.

# %% [markdown]
# Entonces, como esto es un dataframe, puedo ejecutar el método de un dataframe llamado head para mostrar las cinco primeras líneas de un archivo.

# %%
datos_co2.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %% [markdown]
# Una de las características que habíamos hablado de un Excel, vuelvo aquí al Google Sheets, es que tiene hojas, ¿verdad? Entonces, aquí yo no sé exactamente qué hoja estoy viendo. No sé si estoy viendo la primera, la segunda, la tercera, no lo sé. Para esto, voy a añadir una nueva línea de código.

# %% [markdown]
# Usaremos el  método sheet_names, ¿que sería qué cosa? Nombres de las hojas. Quiero que me devuelva una lista con todas las hojas que contiene este Excel, para poder saber con cuál de ellas voy a trabajar.

# %%
pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# Ejecuto esto de aquí y en pantalla me va a aparecer que sí, ese libro de Excel, ese libro de Excel, ese Excel tiene tres hojas. La primera se llama emisiones CO2, emisiones per cápita y fuentes. En realidad, creo que estoy viendo la primera, emisiones CO2. Pero si quisiera ver la segunda hoja, esta de aquí, si quisiera ver la tercera hoja, ¿cómo podría hacerlo? Pues para esto, vamos a explorar los parámetros del método ReadExcel

# %% [markdown]
# ##**Parámetros de la función read_excel**
#
# Documentación: https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Vamos a crear una variable "percapita" par  que nos almacene el resultado de esa hoja emisiones_percapita

# %%
percapita = pd.read_excel(archivo, sheet_name='emisiones_percapita')

# %% [markdown]
# Visualizamos las 5 primeras lineas   con .head()

# %%
percapita.head() #visualiza las primeras 5 lineas de la hoja de excel
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    NaN     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    NaN     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    NaN     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    NaN     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    NaN     NaN     NaN  NaN      NaN
#
#    Quema  Otros
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN

# %% [markdown]
# Con .tail()  veremos  los ultimos 5 lineas  de nuestra DF

# %%
percapita.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %% [markdown]
# para Visualizar  registros aleatorios usamos  .sample(), en este caso  usaremos solo 5 registros aleatorios  .sample(5)

# %%
percapita.sample(5)
# Out:
#                     País ISO 3166-1 alpha-3   Año      Total  Carbón  \
# 2124   Antigua Y Barbuda                ATG  1970  7155695.0     0.0
# 60388         Uzbekistán                UZB  1754        NaN     NaN
# 27317            Jamaica                JAM  1867        NaN     NaN
# 19732    Guiana Francesa                GUF  1898        NaN     NaN
# 55101              Siria                SYR  1907        NaN     NaN
#
#           Aceite  Gas  Cemento  Quema  Otros
# 2124   7155695.0  0.0      0.0    0.0    NaN
# 60388        NaN  NaN      NaN    NaN    NaN
# 27317        NaN  NaN      NaN    NaN    NaN
# 19732        NaN  NaN      NaN    NaN    NaN
# 55101        NaN  NaN      NaN    NaN    NaN

# %% [markdown]
# Ahora  veremos el contenido dela Hoja fuentes de nuestro libro de excel  datos_co2

# %%
fuentes = pd.read_excel(archivo, sheet_name='fuentes')

# %%
fuentes.head()
# Out:
#          País ISO 3166-1 alpha-3   Año   Total  Carbón  Aceite     Gas  \
# 0  Afganistán                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afganistán                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afganistán                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afganistán                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afganistán                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cemento   Quema   Otros Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %%
fuentes.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
# ...

# %% [markdown]
# Vamos a examinar dos parámetros más de esta función, que ya lo hemos hecho en el primer capítulo. Vamos a examinar nRows y useCols para escoger solamente unas columnas y unas filas de todo el archivo para poder entregar como el análisis que el supervisor me ha solicitado.

# %% [markdown]
# Muy bien. Vamos, entonces, a generar intervalos. Para esto, voy a crear una nueva variable, intervalo, y voy a leer nuevamente el archivo Excel. Estoy leyendo el archivo Excel de la hoja principal, la primera hoja, Emisiones CO2.

# %% [markdown]
# Digamos que yo solamente quiera las primeras cuatro columnas.  Si abro aquí el Google Sheets, que es el Excel Online, si quisiera las cuatro columnas, ¿qué es lo que harían en un archivo de Excel para seleccionar solamente las cuatro columnas? Seleccionan la primera y arrastran hasta la cuarta columna. Es decir, están seleccionando todo el intervalo entre A y D![image.png](data:image/png;base64,...)

# %% [markdown]
# ¿Ven aquí? Que ya se colocó entre A y D. Pues vamos a copiar eso, porque eso es exactamente lo que quiero seleccionar en mi intervalo. Para esto, voy a únicamente adicionar como parámetro useCols, que es lo que aprendimos a hacer en el primer capítulo, ¿verdad? Y voy a decir, hey, selecciona el intervalo de columnas de la A a la D. Y ya está. Me va a seleccionar únicamente las primeras cuatro columnas de la hoja Emisiones CO2 del archivo Excel original y lo va a guardar en intervalo.

# %%
intervalo = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols= 'A:D')

# %%
intervalo
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# También podemos hacerlo para las filas,Vamos a copiar esta misma lectura. Vamos a generar una nueva línea de código donde estoy abriendo el archivo original, la hoja Emisiones CO2, restringiendo solamente las primeras cuatro columnas, pero ahora vamos a seleccionar únicamente diez filas del archivo original, es decir, ya no las 63,104,  con el parámetro nRows,  Adicionamos ese parámetro nRows y colocamos aquí el número de filas que queríamos. En esta ocasión voy a seleccionar las diez primeras filas. Lo voy a guardar en otra variable para que no se confunda intervalo_2

# %%
intervalo_2 = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols= 'A:D', nrows=10)

# %%
intervalo_2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# uy bien. Hemos aprendido, entonces, a leer archivos Excel, seleccionar las columnas más importantes y seleccionar los registros de los países, digamos, los diez primeros, que resumen el análisis que quería entregar para mis jefes. Ahora que ya está listo el análisis, vamos a exportar este archivo o este dataframe en un archivo Excel. Hemos aprendido ya a leer el archivo Excel, ahora vamos a aprender a escribirlo

# %% [markdown]
# ##**Escribiendo archivos Excel**

# %% [markdown]
# Muy bien, ya tenemos  ahora  si los  Dfs  con los datos  que nuestro jefe solicito ahora  vamos a guardar el archivo de excel para  que  puedan visualizarlo.

# %%
intervalo.to_excel('co2_percapita.xlsx', index=False)

# %%
pd.read_excel('co2_percapita.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# ##**Leyendo datos de Google Sheets**

# %% [markdown]
#  ya hemos subido hasta aquí las tres hojas, con las filas, las columnas, todo completo, Una vez que está importado en Google Sheets, puedes dar acceso a este libro a quien quieras, aquí, haciendo clic en compartir.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# y copiamoe ese link en la siguiente celda

# %% [markdown]
# link https://docs.google.com/spreadsheets/d/1FNUy08pJH-Ak5LWTsVhQzIKGqSfjceoKoyd1qql4dNQ/edit?usp=sharing

# %% [markdown]
# Ahora para poder importarlo y  trabajarlo en nuestros Dataframes necesitamos in ID.  el  cual está escondido en el link que acabamos e  copiar  y pegar en la celda  anterior.
#
# Se encuentra despues de la "/d/"  y antes de la ultima diagonal del elnace "/e"
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ¿qué significa el id?. El id es el identificador de tu Excel, Es como el DNI, por decirlo así, el documento del Excel, es así que podemos encontrarlo desde cualquier lugar, es así como se llama.

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# Este edit sharing no sirve. ¿Por qué? Porque esto solamente sirve si estamos visualizando desde aquí, pero si queremos que se comunique el Google Sheets con el Google Colab, tenemos que usar la API de Google Sheets que permite que interactúe con el Google Colab. Y para esto, después de esta diagonal, tenemos que utilizar o añadir  "gbiz", Otra diagonal  "/" , y  "tq" . Ya está.

# %% [markdown]
# Estas dos palabras son unas palabras clave de una URL que indica que se están conectando una hoja de Excel o un libro de Excel online con el Google Colab para que pueda ser visualizado dentro de Google Colab. Si no añado estas palabras, no voy a poder visualizarlo dentro de Google Colab,

# %% [markdown]
#  Otra cosa que tengo que añadir es un parámetro de la URL, que es tqx.out:csv. ¿Qué es esto? Bueno, este último parámetro que acabo de añadir a la URL es el formato de salida que quiero leer en Google Colab. Es decir, ¿cómo quiero leer ese archivo que se encuentra en este enlace aquí? ¿Lo quiero leer como un texto, lo quiero leer como un CSV, lo quiero leer como un JSON? En este caso, voy a utilizar el formato CSV porque es un formato que ya hemos trabajado en el primer capítulo, entonces ya conocemos cómo importarlo, cómo leerlo.

# %% [markdown]
# Y, por último, este símbolo aquí, amperson "&" y la palabra sheet, que es un separador. Estoy indicando que quiero llevar desde Google Sheets,la hoja.

# %% [markdown]
# y  asi  es como tendrá que quedar ![image.png](data:image/png;base64,...)

# %%
sheet_id = '1FNUy08pJH-Ak5LWTsVhQzIKGqSfjceoKoyd1qql4dNQ'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %% [markdown]
#  No necesariamente especifico cuál hoja, pero estoy llevando la primera hoja. Cuando no especifico el nombre de la hoja, por defecto, lleva la primera hoja  Emisiones CO2. Entonces, voy a llevar la primera hoja en este enlace.

# %%
import pandas as pd
datos_co2_sheets = pd.read_csv(url)

# %%
datos_co2_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año  ...        Quema        Otros Per Capita
# 0      Afganistán                AFG  1750  ...          NaN          NaN        NaN
# 1      Afganistán                AFG  1751  ...          NaN          NaN        NaN
# 2      Afganistán                AFG  1752  ...          NaN          NaN        NaN
# 3      Afganistán                AFG  1753  ...          NaN          NaN        NaN
# 4      Afganistán                AFG  1754  ...          NaN          NaN        NaN
# ...           ...                ...   ...  ...          ...          ...        ...
# 63099      Global                WLD  2017  ...  391.992.176  302.294.047  4.749.682
# 63100      Global                WLD  2018  ...  412.115.746  302.478.706  4.792.753
# 63101      Global                WLD  2019  ...  439.253.991  306.638.573  4.775.633
# 63102      Global                WLD  2020  ...  407.583.673  296.301.685  4.497.423
# ...

# %% [markdown]
# Tengo tres hojas en el Excel. ¿Y si yo quisiera la segunda hoja?  vamos a ajustar aquí el script. Nada más. No estamos utilizando el readExcel para poder utilizar aquel parámetro sheets igual nombre de hoja para seleccionar o abrir únicamente la hoja que queremos abrir.
#
# Estamos utilizando el readExcel, entonces no podemos utilizar ese parámetro, pero sí podemos abrir la hoja que queramos de esta forma.
#
# La única modificación que podría hacer aquí es añadir una nueva variable, sheetName, que es la hoja que quiero abrir, colocar entre comillas simples la hoja, el nombre de la hoja, en este caso, emisiones_percapita, que es la segunda hoja, Y aquí voy a llamarle url_percapita, que es la URL ya formateada llamando únicamente a la hoja emisiones_percapita. Aquí tengo que hacer alguna alteración, ¿verdad? El sheetId continúa siendo el mismo, porque es el mismo libro de Excel.

# %% [markdown]
# Recuerden, este es el id del libro. Lo único que tendría que cambiar aquí es  El sheet darle un igual y ahora sí pasarle el nombre de la hoja exacta que quiero abrir, que sería emisiones_percapita.
#
# Para no estar escribiendo textualmente emisiones_percapita, voy a nuevamente utilizar la fString. Voy a colocar entre llaves la variable que ya contiene el nombre de esa hoja. Y ya está, que sería sheetName,  ya contiene esa hoja.  con esto de aquí, ya va a direccionar este URL, ya va a direccionar directamente esta segunda hoja.

# %%
sheet_id = '1FNUy08pJH-Ak5LWTsVhQzIKGqSfjceoKoyd1qql4dNQ'
sheet_name = 'emisiones_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita_sheets = pd.read_csv(url_percapita)

# %%
percapita_sheets.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total  ...  Gas Cemento Quema Otros
# 0  Afganistán                AFG  1750   NaN  ...  NaN     NaN   NaN   NaN
# 1  Afganistán                AFG  1751   NaN  ...  NaN     NaN   NaN   NaN
# 2  Afganistán                AFG  1752   NaN  ...  NaN     NaN   NaN   NaN
# 3  Afganistán                AFG  1753   NaN  ...  NaN     NaN   NaN   NaN
# 4  Afganistán                AFG  1754   NaN  ...  NaN     NaN   NaN   NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# Y asi  se manejaria  cambiando los parametros   para  leer  la  tercer Hoja de mi excel

# %%
sheet_id = '1FNUy08pJH-Ak5LWTsVhQzIKGqSfjceoKoyd1qql4dNQ'
sheet_name = 'fuentes'
url_fuentes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
fuentes_sheets = pd.read_csv(url_fuentes)

# %%
fuentes_sheets.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  ...   Quema   Otros Per Capita
# 0  Afganistán                AFG  1750  ...  [NONE]  [NONE]     [NONE]
# 1  Afganistán                AFG  1751  ...  [NONE]  [NONE]     [NONE]
# 2  Afganistán                AFG  1752  ...  [NONE]  [NONE]     [NONE]
# 3  Afganistán                AFG  1753  ...  [NONE]  [NONE]     [NONE]
# 4  Afganistán                AFG  1754  ...  [NONE]  [NONE]     [NONE]
#
# [5 rows x 11 columns]

# %% [markdown]
# Ok, ahí está, la misma información, y es así como se lee archivos o libros de Excel viniendo de Google Sheets.
#
# Es un poco diferente, utilizamos unos métodos un poco diferentes que si utilizásemos ReadExcel, pero es posible de leer, de automatizar, de parametrizar, y de transformar en un dataframe, que ahí ya podemos hacer los análisis que queramos.
#
# Muy bien, hemos aprendido cómo trabajar con libros de Excel en archivos físicos y con libros de Excel en archivos online.

# %% [markdown]
# #Desafío: leyendo datos de otro link
#
#
# Es hora de que pongas a prueba los conocimientos desarrollados durante la clase.
#
# Tenemos un [link de Google Sheets](https://cdn3.gnarususercontent.com.br/1980-pandas-e-s/emisiones_carbono_mundo.xlsx) que contiene datos importantes sobre las emisiones de dióxido de carbono en todo el mundo.
#
# El conjunto de datos se obtuvo de [Kaggle](https://www.kaggle.com/datasets/koustavghosh149/co2-emission-around-the-world) y consta de las emisiones de CO2 per cápita de todos los países del mundo entre 1990 y 2019.
#
# En este desafío, tu función es leer este link de Google Sheets y luego guardar el DataFrame obtenido en formato CSV.

# %% [markdown]
# link https://docs.google.com/spreadsheets/d/1clj6rGaGlvZaLto2lgfFA7lodefC0OJgC86WgDm1nMU/gviz/tq?tqx=out:csv&sheet

# %%
import pandas as pd

sheet_id = '1clj6rGaGlvZaLto2lgfFA7lodefC0OJgC86WgDm1nMU'
#url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-368533936.py in <cell line: 0>()
# ----> 1 datos = pd.read_csv(url)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %% [markdown]
# ###Lo que aprendimos
#
# En esta aula, aprendimos a:
#
# 1. Entender lo qué es una hoja de cálculo;
# 2. Leer un archivo en formato XLSX;
# 3. Identificar páginas en una hoja de trabajo;
# 4. Leer páginas e intervalos específicos de una hoja de trabajo;
# 5. Leer sólo unas pocas líneas de una hoja de cálculo;
# 6. Escribir un archivo en formato XLSX;
# 7. Importar datos de Google Sheets.

# %% [markdown]
# #**Aula 03 Leyendo Archivos JSON**

# %% [markdown]
# Los archivos JSON (JavaScript Object Notation)son un formato de texto ligero para almacenar e intercambiar datos estructurados, legible tanto por humanos como por máquinas.
#
# Se basan en pares de clave-valor, similares a los objetos de JavaScript, y son ampliamente utilizados para la comunicación entre aplicaciones web y servidores, así como para almacenar configuraciones y datos en bases de datos NoSQL

# %% [markdown]
# ##**Importando Archivos JSON**

# %%
import pandas as pd

# %%
datos_pacientes = pd.read_json('pacientes.json')

# %%
datos_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %% [markdown]
# Pero, ojo, no siempre es tan fácil así. Muchas veces, una columna contiene un diccionario dentro de la columna. Es decir, existen informaciones anidadas. Existen diccionarios dentro de diccionarios. Entonces, si nosotros leemos este tipo de documentos JSON que no contienen información anidada, vamos a poder visualizar correctamente. Pero si, por si acaso, tuviésemos un archivo con información anidada, esta lectura ya no nos serviría.

# %% [markdown]
# Vamos a intentar demostrar eso. Tenemos el archivo pacientes2 que tiene información anidada.

# %%
datos_pacientes2 = pd.read_json('pacientes_2.json')

# %%
datos_pacientes2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# Y observen ustedes, como les había indicado, este DataFrame, algunas columnas tienen la información simple, básica, pero en algunas otras columnas, la información está anidada. Es decir, contiene diccionarios dentro del diccionario principal

# %% [markdown]
# Entonces, de esta forma, nosotros no podemos leer las informaciones de los pacientes, ¿verdad? Tenemos que entrar a este nuevo diccionario y comenzar a retirar todas las informaciones que contiene esta variable. ¿Cómo hacer esto? No con este método, ¿verdad? No nos sirve. Tenemos que nuevamente examinar los parámetros dentro del método read_json y ver cuál de estos nos serviría para poder abrir estas informaciones en columnas diferentes.

# %% [markdown]
# ##**Normalizando Arcivos JASON**

# %% [markdown]
# Vamos a intentar extraer estas informaciones anidadas para nuevas columnas, normalizando el archivo JSON,

# %% [markdown]
# Y voy a llamar a ***pandas.json_normalize*** , este es el método de pandas que normaliza un JSON, cuando digo normaliza quiero decir que va a coger esta información y la va a expandir en nuevas columnas. Para cada una de las llaves que encuentre dentro, incluso si encuentra este tipo de llaves, llaves anidadas

# %%
df_normalizado = pd.json_normalize(datos_pacientes2['Pacientes'])

# %%
df_normalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# Ya tenemos todas las columnas separadas

# %% [markdown]
# para saber un poco mas de este  tema de normalizacion  se adjunta este link [https://app.aluracursos.com/course/pandas-e-s-diferentes-formatos-archivo/task/86141](https://app.aluracursos.com/course/pandas-e-s-diferentes-formatos-archivo/task/86141)

# %% [markdown]
# ##**Escribiendo Archivos JASON**

# %%
df_normalizado.to_json('historico_pasientes_norm.jason')

# %%
pd.read_json('historico_pasientes_norm.jason')
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ###Para saber más: obteniendo archivos JSON de APIs

# %% [markdown]
# Para obtener datos en formato JSON podemos utilizar una API (Application Programming Interface). Es una interfaz de programación de aplicaciones que permite la comunicación entre diferentes programas o sistemas.
#
# Hay varios formatos que se pueden utilizar en las API y uno de los más comunes es JSON (JavaScript Object Notation). JSON es un formato ligero para intercambiar información entre sistemas que utiliza la notación basada en objetos de JavaScript.
#
# Tenemos la siguiente situación-problema:
#
# “Una empresa de alimentos saludables tiene problemas con la popularidad de sus productos. A pesar de ofrecer opciones saludables, muchos clientes se muestran reacios a comprar los productos debido a la falta de información sobre los valores nutricionales de las frutas que se utilizan en la producción de alimentos”.
#
#
# Ante esta situación podemos acceder a una API llamada [Fruitvice](https://fruityvice.com) para recopilar información detallada sobre los valores nutricionales de las frutas que se utilizan en los productos. Con esta información, la empresa podrá actualizar sus empaques y materiales de marketing para resaltar los valores nutricionales de las frutas y así atraer más clientes que buscan opciones saludables. Además, la empresa puede utilizar la información para desarrollar nuevos productos que satisfagan aún más las necesidades nutricionales de su clientela.
#
#
#
# Una forma común de acceder a las API es a través de la biblioteca [requests](https://pypi.org/project/requests/). Para eso, también es necesario importar el módulo json:
# (En GoogleColab: !pip install requests para poder importar)
#
#
# *import requests*
#
# *import json*
#
# Los datos de API Fruitvice se obtendrán con la función request.get('url'). Dentro de ella pasamos la dirección API seguida de api/fruit/all para obtener los datos de todas las frutas.
#
#
# datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')
#
#
# Conseguimos recuperar los resultados utilizando la función json.loads(). Para ello es necesario pasar la variable datos_frutas, previamente creada con el atributo text que devuelve el contenido de la respuesta.
#
#
# resultado = json.loads(datos_frutas.text)
#
# Luego podemos obtener una vista previa del DataFrame.
#
# pd.DataFrame(resultado)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Lo que aprendimos
#
#
# En esta aula, aprendimos a:
#
# * Comprender qué es el formato JSON;
# * Leer un archivo en formato JSON;
# * Normalizar datos de un archivo JSON;
# * Escribir un archivo en formato JSON;
# * Obtener archivos JSON de las API.

# %% [markdown]
# #**Aula 4 - Leyendo páginas en HTML e XML**

# %% [markdown]
# ##**Importando páginas web**

# %% [markdown]
# Nuevamente, nos encontramos con nuestro jefe o supervisor y nos dice: "Alejandro, acabamos de cerrar un contrato con la empresa X y vamos a crear para ellos un recomendador de películas. Vamos a ofrecer a sus clientes novedades o películas nuevas que estén de acuerdo con sus gustos".

# %% [markdown]
# Perfecto, le digo, "¿Dónde está esa base de datos de películas para trabajar?" Y nuestro jefe nos dice, "pues, para eso estás tú. Necesitamos que nos encuentres una página de películas para que nosotros podamos trabajar y ofrecer a sus clientes".
#
# Y yo digo, "pues, gracias. Tenemos que buscar ahora una página de películas". Y me encontré con esta página web. Este sitio aquí en Wikipedia que tiene las películas de los últimos 100 años

# %% [markdown]
# Entonces vamos a importar esa página web que está en nuestro archivo del proyecto para que esté disponible siempre por aquí. Recuerden que por aquí podemos subir archivos a nuestro Google Colab. Entonces vamos a buscar la página web que he guardado en el aula 4, Data, Películas Wikipedia.

# %%
import pandas as pd

# %%
datos_html = pd.read_html('peliculas_wikipedia.html')

# %%
datos_html
# Out:
# [                                                    0  \
#  0                                                1998
#  1                                                1999
#  2                                                2000
#  3                                                2001
#  4                                                2002
#  5                                                2003
#  6                                                2004
#  7                                                2005
#  8                                                2005
#  9                                                2006
#  10                                               2006
#  11                                               2007
#  12                                               2008
#  13  .mw-parser-output .hlist dl,.mw-parser-output ...
#
#                                                      1
#  0                                          100 Movies
# ...

# %% [markdown]
# Y como pueden ver aquí, hay algo raro.  Esto no se parece con una tabla de data frames. ¿Por qué? Porque esta tabla de data frames, en realidad, ***no es una única tabla***. Recuerden que la página web a la cual nos dirigimos tenía tres tablas.
#
# Entonces, lo que nos está devolviendo esta lectura son las tres tablas. Entonces, es una lista. Sabemos que cuando comienza en corchete, nos referimos a una lista. Es una lista con tres tablas o tres data frames, en este caso.

# %% [markdown]
# Incluso, podría yo inspeccionar el tipo de datos a que se refiere esta variable colocándola dentro del método type.

# %%
type(datos_html)
# Out:
# list

# %% [markdown]
# Es una lista porque comenzaba con corchete.Sabemos que corchete es la variable indicador de una lista.

# %% [markdown]
# Si yo quisiera ver el tamaño de esa lista, puedo también verla utilizando el método len. Len es para ver el tamaño, el size de una variable

# %%
len(datos_html)
# Out:
# 3

# %% [markdown]
#  En este caso, veo que el resultado es 3. Quiere decir que el contenido de datos HTML es una lista de tres objetos, de tres tablas,

# %% [markdown]
# Cuál era la tabla que me interesaba? ¿Qué posición ocupaba? No era la primera,  Ocupaba la segunda posición. Esa es la tabla que quiero exactamente leer.
#
# Entonces, que ya sabemos cuál es la posición que nos interesa, la segunda, vamos a extraer únicamente la tabla de datos HTML que ocupa la segunda posición. Muy fácil. Venimos a un nuevo código, examinamos datos HTML y entre corchetes coloco la segunda posición.
#
# ¿Cuál sería el número que equivale a esa segunda posición? En Python, recuerden que comenzamos a contar desde cero. Entonces, la segunda posición sería 0, 1. El valor 1. Listo. Esa es la tabla de la segunda posición.
#
# Voy a guardar en una nueva variable, top_películas. Ok. Voy a guardar aquí. Estoy extrayendo el elemento de segunda posición de datos HTML. Todo esto de acá. Y lo estoy guardando en top_películas.

# %%
top_peliculas = datos_html[1]

# %%
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# Examinamos ahora el resultado de top_películas. Ahora observaré que sí tengo exactamente el data frame que quería, que era exactamente esta tabla, La que ocupaba la segunda posición en toda la página web, que contiene la información de las películas, el año de lanzamiento, el director, la compañía que la produjo y el ranking.

# %% [markdown]
# ##**Para saber más: ¿Qué es HTML?**
#
#
# HTML (Hypertext Markup Language - Lenguaje de marcación de hipertexto) es el código que utilizamos para estructurar una página web y su contenido. HTML consta de una serie de elementos que se utilizan para delimitar o agrupar diferentes contenidos para que aparezca o actúe de una determinada manera.
#
#
# Un documento HTML comienza con la etiqueta <code>&lt;html&gt;</code> y termina con la etiqueta <code>&lt;/html&gt;</code>.
#
# "También contiene un encabezado (<code>&lt;head&gt;</code> )que describe el título de la página y otras informaciones relevantes; y un cuerpo (<code>&lt;body&gt;</code>) que contiene el contenido de la página. El encabezado y el cuerpo están delimitados por las etiquetas <code>&lt;head&gt;</code> y <code>&lt;/head&gt;</code>, y <code>&lt;body&gt;</code> y <code>&lt;/body&gt;</code>, respectivamente.
#
# Dentro del cuerpo podemos utilizar diversos elementos para crear la estructura del contenido. Observe cada detalle en el siguiente ejemplo:
#
# * tags <code>&lt;h1&gt;</code>  a <code>&lt;h6&gt;</code>: crear títulos y subtítulos.
#
# * tags <code>&lt;p&gt;</code>: crear párrafos.
#
# * tags <code>&lt;ul&gt;</code> y <code>&lt;li&gt;</code>: crear listas no ordenadas.
#
# * tags <code>&lt;img&gt;</code>: insertar imágenes.
#
# * tags <code>&lt;table&gt;</code>, <code>&lt;tr&gt;</code>,<code>&lt;th&gt;</code> y <code>&lt;td&gt;</code>: crear tablas.
#
#
# Además, podemos usar atributos en elementos HTML para especificar propiedades adicionales. Por ejemplo:
#
# podemos usar el atributo <code>src</code> en la etiqueta <code>&lt;img&gt;</code> para indicar la dirección de la imagen que queremos mostrar, o el atributo <code>href</code> en la etiqueta <code>&lt;a&gt;</code> para indicar la dirección del link que queremos crear.

# %% [markdown]
# ##Escribiendo Archivos HTML

# %% [markdown]
# Muy bien, vemos que ya tenemos la información que necesitábamos de esta página web en nuestro DataFrame, que está en nuestra base de datos de Python, DataFrame. ¿Cómo lo exportamos nuevamente a HTML?  HTML es bueno porque cuando lo exportamos podemos descargarlo y luego podemos visualizarlo desde cualquier computadora, sin muchas herramientas necesarias. Se abre directamente en un navegador.

# %%
top_peliculas.to_html('top_peliculas.html')

# %% [markdown]
# Una vez descargado el aechivo  top_peliculas.html si lo ejecutamos  con uestro navergador, se veria asi ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tambien lo podemos visualizar  directamente desde aqui

# %%
pd.read_html('top_peliculas.html')
# Out:
# [    Unnamed: 0                          Film  Release year  \
#  0            0                  Citizen Kane          1941
#  1            1                    Casablanca          1942
#  2            2                 The Godfather          1972
#  3            3            Gone with the Wind          1939
#  4            4            Lawrence of Arabia          1962
#  ..         ...                           ...           ...
#  95          95                 The Searchers          1956
#  96          96              Bringing Up Baby          1938
#  97          97                    Unforgiven          1992
#  98          98  Guess Who's Coming to Dinner          1967
#  99          99           Yankee Doodle Dandy          1942
#
#                  Director                    Production companies  Rank
#  0           Orson Welles                      RKO Radio Pictures     1
#  1         Michael Curtiz                   Warner Bros. Pictures     2
# ...

# %% [markdown]
# Ya lo hicimos. Pero cuando queramos pasar a nuestro supervisor, es mejor pasar esta tabla en un CSV, ¿verdad? Porque si no, nuestro supervisor se va a quedar un poco loco para intentar abrir esto de aquí. Está acostumbrado a Excel

# %%
top_peliculas.to_csv('top_peliculas_1998.scv', index=False)

# %%
datos = pd.read_csv('top_peliculas_1998.scv')
datos.head()
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %% [markdown]
# ##Leyendo/escribiendo arcivos XML

# %% [markdown]
#  Nuestra supervisora nos sorprendió. Mira que fulano también obtuvo información sobre películas, Quiero que analices esto, porque está en un formato un poco extraño, es un formato llamado XML.

# %% [markdown]
# Primero, el XML, ya saben qué es, Extensible Markup Language ***(Lenguaje de Marcado Extensible)***
#
# Para abrirlo, es similar al HTML, vamos a intentar visualizar su estructura. Para eso podemos abrirlo con un navegador, Google Chrome, por ejemplo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ya lo tengo abierto aquí en Google Chrome, es este de aquí. La estructura es similar a un HTML, con algunas consideraciones. El XML, claro, tiene un poco más de densidad, es un poco más denso que el HTML, por eso es Extensible, es extensivo.

# %% [markdown]
# <code>Data</code>, esta clave <code>Data</code> nos indica dónde comienza la información de nuestro documento, comienza por <code>Data</code>, cierra por <code>/Data</code>. <code>Row</code> nos indica que va a comenzar una nueva fila, de un nuevo registro, una nueva fila. Todo el contenido de una fila se encapsula dentro de estas llaves <code>Row</code>. Y dentro de estas llaves <code>Row</code> tenemos varias otras llaves que identifican cada una de las columnas que tenemos para esta fila. Entonces, la columna  <code>index</code>,  <code>poster_link</code>,  <code>series title</code>, dependiendo de cuántas columnas tengamos para cada fila, ¿vale? Y así es como se estructura este tipo de archivos XML.

# %%
import pandas as pd

# %%
datos_IMDB = pd.read_xml('imdb_top_1000.xml')
datos_IMDB
# Out:
#      index                                        Poster_Link  \
# 0        0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..     ...                                                ...
# 995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# ...

# %%
datos_IMDB.to_xml('peliculas_IMDB.xml')
datos_IMDB.to_csv('peliculas_IMDB.csv')
datos_IMDB.to_html('peliculas_IMDB.html')

# %% [markdown]
# Lo que aprendimos
#
#
# En esta aula, aprendimos a:
#
# * Inspeccionar una página web;
# * Leer datos de una página web;
# * Escribir archivos HTML;
# * Comprender cómo está
# * estructurado el formato XML;
# * Leer datos en formato XML;
# * Escribir archivos en formato XML.

# %% [markdown]
# #**Aula 05 - Leyendo Banco de Datos**

# %% [markdown]
# ##Creando una banco de datos Local

# %% [markdown]
# Acabamos de firmar un contrato con un banco. El banco tiene una base de clientes muy extensa y poderosa, pero no logran extraer ningún insight (perspectiva) de esta base de datos. Esta base de datos está en un formato CSV, un formato comprensible esta vez. Pero necesito realizar algunas consultas más específicas, unas consultas más avanzadas. Y para esto quiero que, por favor, cargues esta base en un banco de datos. Vas a crear un banco de datos y vas a generar algunas consultas para poder realizar algunos insights sobre esta base. Te dejo con esto, nos vemos.

# %% [markdown]
# Recibimos la base de datos, está en un archivo CSV, pero la pregunta es, ¿podemos trabajar este tipo de archivos como SQL dentro de Python? Y la respuesta es sí, Por cierto, ¿saben lo que es o lo que significa SQL? Structured Query Language (Lenguaje de Consulta Estructurado). Y por ser estructurado, podemos ejecutar diferentes tipos de consultas en alguna base de datos. Base de datos que puede ser un CSV, que puede ser una tabla en Excel, etcétera. Cualquier tipo de este tipo de archivos podemos subirlos y convertirlos a un formato de base de datos dentro de Python. Pero, siempre hay un pero, La historia nunca es tan bonita, porque si no, no tendríamos ese valor que tenemos ahora las personas científicas de datos. Tenemos que utilizar una biblioteca llamada SQL Alchemy dentro de Python para poder realizar esta interpretación del banco de datos.

# %% [markdown]
# Para crear un banco de datos local, necesitamos importar, la biblioteca `SQL Alchemy`. esta es la biblioteca que va a hacer toda la magia,. De esta biblioteca `SQL Alchemy` hay que importar algunos métodos.
#
# `createEngine`, que es el que va a crear el motor de datos que va a ejecutar el SQL en nuestro banco de datos. Este que nos genera todo el entorno, el entorno de banco de datos. hay que ejecutarlo,
#
# `Metadata` que va a guardar la información de las tablas que vamos a tener en nuestro banco de datos, no solamente los nombres de la tabla, sino los atributos, tipo de datos, etcétera. Todo lo que es el metadato es como un diccionario de todas las tablas y sus columnas.
#
# `Table` o el método table para poder trabajar con las tablas, consultar las tablas, acceder a las tablas.
#
# `Inspect` para inspeccionar bancos de datos, para saber qué tablas tengo dentro de un banco de datos o inspeccionar una tabla para saber qué atributos tengo dentro de esa tabla. El método inspect es como un investigador que nos dice qué es lo que hay en algún lugar.
#
# `text` , para convertir las ***queries*** en un tipo de datos de texto que se puede entender dentro de las consultas. Ustedes ya van a ver para qué sirve cada uno de estos cuando estemos construyendo nuestro primer banco de datos. Ya está, vamos a importarlo.

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %% [markdown]
# No vamos a subir la tabla primero, ***Tenemos que crear,  El banco de datos local***. Tenemos que crear el motor que va a soportar las tablas.
#
# .
#
#
# Para esto, podemos utilizar uno de los bancos de datos que ya viene instalado, que ya se encuentra instalado en el Google Cloud.
#
# Me refiero al SQLite. SQLite ya viene por defecto instalado dentro de Google Cloud. Entonces, no necesitamos instalar con un paquete externo o entrar a la página de ese banco de datos e instalarlo. No, ya está todo instalado. Es el que vamos a utilizar ahora porque es mucho más fácil.
#
# Existen otros bancos de datos,  MySQL, Oracle o SQL Server.  que también podemos utilizar combinado con Python, pero para evitarnos todo ese súper mega tutorial que debe ser instalar uno de estos bancos de datos en Python, vamos a restringirnos al SQLite que ya viene por defecto instalado y solamente tenemos que utilizarlo.

# %% [markdown]
# Vamos a crear entonces este motor, `createEngine`, que va a crear el motor de datos. Dentro de los paréntesis tengo que escribir el tipo, el tipo de motor o el banco de datos que quiero crear. En este caso, quiero crear SQLite

# %% [markdown]
# Ahora, voy a colocar dos puntos porque no solamente tengo que seleccionar el motor que quiero usar, sino dónde se va a ejecutar.
#
# En este caso, quiero que se ejecute en memoria, con la memoria de Google Cloud, la memoria local. Para esto, voy a añadir tres barras, dos puntos de nuevo, memory y cierro con dos puntos.
#
# En esta, memory significa que quiero utilizar la memoria local del Google Cloud para ejecutar el motor de SQLite. Y este motor o esta creación del engine o creación del motor, se tiene que almacenar en algún lugar, Para estar siempre referenciándolo.
#
# Así que voy a crear una variable engine que va a recibir el resultado de este motor SQLite que voy a crear y vamos a guardarla en engine

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# Ahora, cuando cree las tablas, cuando cree las consultas o las inspecciones, cualquier query que necesite ejecutar en el banco de datos, voy a referenciar siempre al engine.
#
# Esta es la base, el piso, el motor que nos da soporte a la vida. Este engine ya es el motor que vamos a utilizar para construir nuestras tablas.
#
# Ahora sí podemos construir tablas, comenzar a ver esta base de datos que nuestro jefe o nuestro supervisor nos ha dejado de los clientes del banco e importarla en una tabla de este motor.

# %% [markdown]
# ###Para saber más: bases de datos y SQLAlchemy
#
# Las bases de datos son sistemas que permiten el almacenamiento, organización y recuperación de información de forma estructurada y eficiente. Se utilizan ampliamente en muchas áreas, desde la gestión empresarial hasta la investigación científica. Una base de datos bien diseñada puede mejorar significativamente la eficiencia y precisión de las operaciones de una organización.
#
# Existen bases de datos relacionales y no relacionales. Las bases de datos relacionales representan y almacenan datos en tablas. Las bases de datos no relacionales, también conocidas como bases de datos NoSQL (Not Only SQL - No Sólo SQL), utilizan una variedad de estructuras de datos, como documentos, gráfos o pares llave-valor.
#
# Python ofrece varios paquetes y bibliotecas para trabajar con bases de datos, incluyendo SQLite, MySQL, PostgreSQL, Oracle, MongoDB, entre otros. Uno de los paquetes más comunes utilizados para trabajar con bases de datos relacionales en Python es el paquete sqlite3 que ofrece soporte a bases de datos SQLite. Esta base de datos es liviana e integrada, no requiere un servidor separado para ejecutarse y está instalada de forma nativa en Google Colab.
#
# Para trabajar con esta base de datos, podemos usar SQLAlchemy, una biblioteca de mapeo objeto-relacional (ORM), que permite interactuar con bases de datos relacionales usando código Python. Proporciona una capa de abstracción que permite a los desarrolladores trabajar con objetos Python en lugar de lidiar directamente con las complejidades del lenguaje SQL (Structured Query Language - Lenguaje de consulta estructurado).
#
# Uno de los principales beneficios de utilizar SQLAchemy es la capacidad de crear código más legible y fácil de mantener. Con SQLAlchemy, las operaciones de la base de datos se realizan utilizando métodos en objetos Python, lo que hace que el código sea más claro y menos propenso a errores.
#
# Además, SQLAlchemy ofrece soporte a consultas complejas en bases de datos, lo que permite a los desarrolladores extraer fácilmente información relevante de grandes conjuntos de datos. Esto es especialmente útil en aplicaciones que necesitan manejar grandes cantidades de datos.
#
# Puede encontrar más detalles sobre la biblioteca SQLAchemy en la siguiente [documentación](https://www.sqlalchemy.org).

# %% [markdown]
# ##Escribiendo un Banco de Datos

# %% [markdown]
# Muy bien, ha llegado la hora de importar esta base de clientes que nuestro supervisor nos ha proporcionado para una nueva tabla que vamos a generar dentro de este motor de SQL que hemos creado, nuestra variable engine.

# %%
import pandas as  pd

# %% [markdown]
# Ahora tenemos que cargar el nombre del archivo en un dataframe, pero para no estar escribiendo, recordemos el truco, vamos a guardar el nombre del archivo dentro de una variable para solamente referenciar la variable posteriormente.
#
# Esn este caso  la variable se llamará archivo

# %%
archivo = 'clientes_banco.csv'

# %% [markdown]
# Dónde vamos a recibir estos nuevos datos? En una variable` datos`. `datos` será una variable de tipo <code>Dataframe</code> que reciba todos los registros que hemos recibido en el archivo CSV.

# %% [markdown]
# Es un archivo CSV separado por comas, entonces no necesitamos colocar, recuerden ese parámetro, del separador igual a alguna cosa, porque ya está con coma. Es el default, el separador por default, no necesitamos preocuparnos en colocar parámetros adicionales.

# %%
datos = pd.read_csv(archivo)

# %%
datos.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804  32.0    Nivel superior  Relación-estable             2.0
# 1     5008805  32.0    Nivel superior  Relación-estable             2.0
# 2     5008806  58.0  Nivel intermedio            Casado             2.0
# 3     5008808  52.0  Nivel intermedio           Soltero             1.0
# 4     5008809  52.0  Nivel intermedio           Soltero             1.0
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro           12.0           427500.0
# 1           Empleado       Otro           12.0           427500.0
# 2           Empleado  Seguridad            3.0           112500.0
# 3   Business Partner     Ventas            8.0           270000.0
# 4   Business Partner     Ventas            8.0           270000.0
#
#    Tiene_carro                  Vivienda
# 0          1.0    Departamento alquilado
# 1          1.0    Departamento alquilado
# ...

# %% [markdown]
#  Ya habíamos aprendido a leer CSV. Pero ¿por qué teníamos que leer a CSV? Porque necesitamos que ese contenido se encuentre en una variable dataframe para pasarlo a una tabla SQL. Por eso tuvimos que importarlo en un dataframe. ***No se puede pasar de un CSV directo a una tabla. Hay que primero colocarlo en un dataframe, que es lo que ya hemos hecho***.

# %% [markdown]
#  ***Ahora sí, podemos colocar a una tabla SQL.***
#
#  Recuerden que siempre comenzamos colocando la variable que contiene el dataframe. En este caso, datos. Y a partir de aquí, podemos exportarlo a un SQL.

# %%
datos.to_sql('clientes',engine,index=False)
# Out:
# 234258

# %% [markdown]
# ¿Cómo puedo saber si funcionó? ¿Cómo puedo saber si realmente creó una tabla dentro del engine, dentro de nuestro motor? Pues para eso tenemos aquí al `inspector`, Este método,  el inspect,  Para esto podemos crear una variable inspector, que reciba la inspección del motor engine. Lo que estoy haciendo aquí es, estoy generando una variable, que le voy a llamar inspector, que reciba la ejecución del inspect engine. Quiere decir, hey, ***revisa,todo lo que hay dentro del motor engine y guárdalo aquí.***

# %%
inspector = inspect(engine)

# %% [markdown]
# Una vez que lo revise, vamos a examinar nuestra variable inspector que hemos creado, vamos a generarlo dentro de un `print`, para que nos devuelva en pantalla, y puede revisar bastantes cosas,
#
# pero lo que quiero ver es las tablas que ha generado, entonces, para esto puedo llamar `getTableNames`.
#
# Este método que se encuentra dentro de la variable inspector, y solamente dentro de las variables que reciben esta ejecución, puedo utilizar el método `getTableName`, es un método propio de las variables o del método `inspect` de SQL Alchemy.

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %% [markdown]
# Vamos entonces a inspeccionar las tablas, y así es, dentro del engine, dentro de nuestro motor SQL, ya existe una tabla llamada clientes

# %% [markdown]
# Ahora sí, ya tenemos la tabla, ya tenemos el motor, ¿qué nos falta? Generar consultas query, ¿verdad? Consultas SQL o queries SQL, para realizar diferentes tratamientos, diferentes consultas, examinaciones, análisis, etc.
